# %% [markdown]
# ## Text to Speech - Amazon Polly
#
# **Generating the audio**

# %%
import boto3
from IPython.display import HTML, display, Image as IImage

polly_client = boto3.client('polly')

response = polly_client.synthesize_speech(VoiceId='Joanna',
                OutputFormat='mp3', 
                Text = 'This is a sample text to be synthesized.')

filename = "speech.mp3"
file = open(filename, 'wb')
file.write(response['AudioStream'].read())
file.close()

# %% [markdown]
# **Listening the audio**

# %%
audio_url = filename
video_tag = "<audio  controls='controls' width='640' name='Video' src='{0}'></video>".format(audio_url)
video_ui = "<table><tr><td style='vertical-align: top'>{}</td></tr></table>".format(video_tag)
display(HTML(video_ui))
# Out:
# <table><tr><td style='vertical-align: top'><audio  controls='controls' autoplay width='640' name='Video' src='speech.mp3'></video></td></tr></table>

# %% [markdown]
# ## Automatic speech recognition - Amazon Transcribe

# %%
import time
import boto3
import requests
import json


def transcribe_file(job_name, file_uri, transcribe_client):
    transcribe_client.start_transcription_job(
        TranscriptionJobName=job_name,
        Media={'MediaFileUri': file_uri},
        MediaFormat='mp3',
        LanguageCode='en-US'
    )

    max_tries = 60
    while max_tries > 0:
        max_tries -= 1
        job = transcribe_client.get_transcription_job(TranscriptionJobName=job_name)
        job_status = job['TranscriptionJob']['TranscriptionJobStatus']
        if job_status in ['COMPLETED', 'FAILED']:
            print(f"Job {job_name} is {job_status}.")
            if job_status == 'COMPLETED':
                job_url = job['TranscriptionJob']['Transcript']['TranscriptFileUri']
                #print(
                #    f"Download the transcript from\n"
                #    f"\t{job['TranscriptionJob']['Transcript']['TranscriptFileUri']}")
                data  = requests.get(job_url).json()
                print ("\nTranscript: ==========\n {}".format(data['results']['transcripts'][0]))
                print("\nComplete Message: ==========\n{}".format(json.dumps(data, indent=4, sort_keys=True)))
            break
        else:
            print(f"Waiting for {job_name}. Current status is {job_status}.")
        time.sleep(10)


def main():
    transcribe_client = boto3.client('transcribe')
    s3 = boto3.client('s3')
    file_uri = "s3://amazon-rekognition-code-samples-678987013791-us-east-1/media/transcribe-sample.mp3"
    s3_video_url = s3.generate_presigned_url('get_object', Params={'Bucket': 'amazon-rekognition-code-samples-678987013791-us-east-1', 'Key': 'media/transcribe-sample.mp3'})

    video_tag = "<audio  controls='controls' width='640' name='Video' src='{0}'></video>".format(s3_video_url)
    video_ui = "<table><tr><td style='vertical-align: top'>{}</td></tr></table>".format(video_tag)
    display(HTML(video_ui))
    
    transcribe_file('Example-job{}'.format(time.time()), file_uri, transcribe_client)


if __name__ == '__main__':
    main()
# Out:
# <table><tr><td style='vertical-align: top'><audio  controls='controls' width='640' name='Video' src='https://amazon-rekognition-code-samples-678987013791-us-east-1.s3.amazonaws.com/media/transcribe-sample.mp3?AWSAccessKeyId=ASIAZ4FWHT2PRIXKVZDC&Signature=Y9O2JkoLh6iwLX%2FnLwVWZV4XxHo%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEG8aCXVzLWVhc3QtMSJGMEQCIEKWdv5eUt1l0U7nDlwaMT5EYXQZIrSqTodRxG8JrgPVAiBSwy9ByLLQd4rOhGhn2kVyDYTvhWVS0dgj7vOEZ3558ir%2BAgjH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAEaDDY3ODk4NzAxMzc5MSIMVQkPywRFDoDazM3wKtICsgaZSt%2Bh4Vd07qNMgv8BZU9vSjhElshqOQ2w0AcwimaO5dep1t45Y%2BemgvOx4oJjkOjWb0DoaGMSGQWGi8HqWITsHnQt7lHbhXPcbqnMdOTiKrjrINhJemgWsIoLfX8c4a4gQIrjRV1wTJbAPElFSjpq9z0R%2Bb%2B1JKsntT1FpStoVoIjhDmsKafWAisNX8BGxpOb%2FdCY0ajYyRweR3Um2qd4MVJL5M4kN6mJYJtZ%2FyE%2BRw6NFsJ%2F5Supq9DembU%2B1btSCBePRF6cQJUSeZRMFaSDUOiO%2FmBahNEqmcLvWS0wmBCpmLJH8s3RMGvjTIL6JzfistZSXLDZJBWa32JdPhvgwBwfs5P7PJkg3RVMTVbp1Aj4gvWjK3FhEKR4rTv0tVSNjmrotp39HLoEf8SYTwc2Mhdmp6DbaZD64z1V7fMGbtpq1QyVzekRZ2HrhBacFtgwjIvTgwY6xAFn9GgbwlFZuzVRoUK1DFvTQy4RRckzjglLppGNhN%2BMOAt3iAhGmxZjC5m4m0MO2OMtqzs%2Bd%2FrgRlrc0zc13%2B%2FlL%2BTt2OPCpQwqXP2EDjkb7DxhB9x1q53sE%2F6YNxNU9vZLKnF7GMYVjsxyexxelKdVTt8022fa6Ku9wP%2BUURY8%2FuaYQBvfxKrxYL632O%2F4tLH6SKJp5zRheR%2Fmk%2B3MCvPzjjQsEcV8F%2B2%2FN%2BEqX6OTSXG239Aq4rGcPiN1aHNEaj5DwIMV&Expires=1618270134'></video></td></tr></table>
# Waiting for Example-job1618266534.2515216. Current status is IN_PROGRESS.
# Waiting for Example-job1618266534.2515216. Current status is IN_PROGRESS.
# Waiting for Example-job1618266534.2515216. Current status is IN_PROGRESS.
# Job Example-job1618266534.2515216 is COMPLETED.
#
# Transcript: ==========
#  {'transcript': 'Machine learning is employed in a range of computing tasks where designing and programming explicit algorithms with good performance as difficult or infeasible. Example applications include email filtering, detection of network intruders and computer vision. Machine learning is closely related to computational statistics, which also focuses on predictions making through the use of computer. It has strong ties to mathematical optimization, which delivers methods, theory and application domains to the field.'}
#
# Complete Message: ==========
# {
#     "accountId": "678987013791",
#     "jobName": "Example-job1618266534.2515216",
#     "results": {
#         "items": [
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "Machine"
#                     }
#                 ],
#                 "end_time": "0.38",
#                 "start_time": "0.04",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "learning"
#                     }
#                 ],
#                 "end_time": "0.72",
#                 "start_time": "0.38",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "is"
#                     }
#                 ],
#                 "end_time": "0.86",
#                 "start_time": "0.72",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "employed"
#                     }
#                 ],
#                 "end_time": "1.26",
#                 "start_time": "0.86",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "in"
#                     }
#                 ],
#                 "end_time": "1.34",
#                 "start_time": "1.26",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "a"
#                     }
#                 ],
#                 "end_time": "1.4",
#                 "start_time": "1.34",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "range"
#                     }
#                 ],
#                 "end_time": "1.66",
#                 "start_time": "1.4",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "of"
#                     }
#                 ],
#                 "end_time": "1.77",
#                 "start_time": "1.66",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "computing"
#                     }
#                 ],
#                 "end_time": "2.25",
#                 "start_time": "1.77",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "tasks"
#                     }
#                 ],
#                 "end_time": "2.75",
#                 "start_time": "2.25",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.844",
#                         "content": "where"
#                     }
#                 ],
#                 "end_time": "2.97",
#                 "start_time": "2.76",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "designing"
#                     }
#                 ],
#                 "end_time": "3.42",
#                 "start_time": "2.97",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.821",
#                         "content": "and"
#                     }
#                 ],
#                 "end_time": "3.51",
#                 "start_time": "3.42",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.806",
#                         "content": "programming"
#                     }
#                 ],
#                 "end_time": "3.9",
#                 "start_time": "3.51",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "explicit"
#                     }
#                 ],
#                 "end_time": "4.41",
#                 "start_time": "3.9",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "algorithms"
#                     }
#                 ],
#                 "end_time": "5.02",
#                 "start_time": "4.42",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "with"
#                     }
#                 ],
#                 "end_time": "5.25",
#                 "start_time": "5.02",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "good"
#                     }
#                 ],
#                 "end_time": "5.44",
#                 "start_time": "5.25",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.996",
#                         "content": "performance"
#                     }
#                 ],
#                 "end_time": "5.98",
#                 "start_time": "5.44",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.643",
#                         "content": "as"
#                     }
#                 ],
#                 "end_time": "6.11",
#                 "start_time": "5.98",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "difficult"
#                     }
#                 ],
#                 "end_time": "6.55",
#                 "start_time": "6.11",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.99",
#                         "content": "or"
#                     }
#                 ],
#                 "end_time": "6.69",
#                 "start_time": "6.56",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.992",
#                         "content": "infeasible"
#                     }
#                 ],
#                 "end_time": "7.46",
#                 "start_time": "6.69",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.0",
#                         "content": "."
#                     }
#                 ],
#                 "type": "punctuation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "Example"
#                     }
#                 ],
#                 "end_time": "8.26",
#                 "start_time": "7.75",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "applications"
#                     }
#                 ],
#                 "end_time": "8.93",
#                 "start_time": "8.26",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.996",
#                         "content": "include"
#                     }
#                 ],
#                 "end_time": "9.31",
#                 "start_time": "8.93",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "email"
#                     }
#                 ],
#                 "end_time": "9.65",
#                 "start_time": "9.32",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "filtering"
#                     }
#                 ],
#                 "end_time": "10.26",
#                 "start_time": "9.65",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.0",
#                         "content": ","
#                     }
#                 ],
#                 "type": "punctuation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "detection"
#                     }
#                 ],
#                 "end_time": "10.89",
#                 "start_time": "10.35",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "of"
#                     }
#                 ],
#                 "end_time": "11.01",
#                 "start_time": "10.89",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.997",
#                         "content": "network"
#                     }
#                 ],
#                 "end_time": "11.37",
#                 "start_time": "11.01",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.998",
#                         "content": "intruders"
#                     }
#                 ],
#                 "end_time": "11.88",
#                 "start_time": "11.37",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "and"
#                     }
#                 ],
#                 "end_time": "12.04",
#                 "start_time": "11.88",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "computer"
#                     }
#                 ],
#                 "end_time": "12.38",
#                 "start_time": "12.04",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "vision"
#                     }
#                 ],
#                 "end_time": "12.82",
#                 "start_time": "12.38",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.0",
#                         "content": "."
#                     }
#                 ],
#                 "type": "punctuation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "Machine"
#                     }
#                 ],
#                 "end_time": "13.51",
#                 "start_time": "13.14",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "learning"
#                     }
#                 ],
#                 "end_time": "13.75",
#                 "start_time": "13.51",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.998",
#                         "content": "is"
#                     }
#                 ],
#                 "end_time": "13.87",
#                 "start_time": "13.75",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "closely"
#                     }
#                 ],
#                 "end_time": "14.29",
#                 "start_time": "13.87",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "related"
#                     }
#                 ],
#                 "end_time": "14.65",
#                 "start_time": "14.29",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "to"
#                     }
#                 ],
#                 "end_time": "14.79",
#                 "start_time": "14.65",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "computational"
#                     }
#                 ],
#                 "end_time": "15.46",
#                 "start_time": "14.79",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "statistics"
#                     }
#                 ],
#                 "end_time": "16.16",
#                 "start_time": "15.46",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.0",
#                         "content": ","
#                     }
#                 ],
#                 "type": "punctuation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "which"
#                     }
#                 ],
#                 "end_time": "16.44",
#                 "start_time": "16.17",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "also"
#                     }
#                 ],
#                 "end_time": "16.69",
#                 "start_time": "16.44",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "focuses"
#                     }
#                 ],
#                 "end_time": "17.19",
#                 "start_time": "16.69",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "on"
#                     }
#                 ],
#                 "end_time": "17.36",
#                 "start_time": "17.19",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "predictions"
#                     }
#                 ],
#                 "end_time": "18.04",
#                 "start_time": "17.36",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "making"
#                     }
#                 ],
#                 "end_time": "18.59",
#                 "start_time": "18.24",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "through"
#                     }
#                 ],
#                 "end_time": "19.03",
#                 "start_time": "18.59",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "the"
#                     }
#                 ],
#                 "end_time": "19.18",
#                 "start_time": "19.04",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "use"
#                     }
#                 ],
#                 "end_time": "19.36",
#                 "start_time": "19.18",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "of"
#                     }
#                 ],
#                 "end_time": "19.45",
#                 "start_time": "19.36",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "computer"
#                     }
#                 ],
#                 "end_time": "19.94",
#                 "start_time": "19.45",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.0",
#                         "content": "."
#                     }
#                 ],
#                 "type": "punctuation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.989",
#                         "content": "It"
#                     }
#                 ],
#                 "end_time": "20.47",
#                 "start_time": "20.3",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "has"
#                     }
#                 ],
#                 "end_time": "20.62",
#                 "start_time": "20.47",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "strong"
#                     }
#                 ],
#                 "end_time": "20.91",
#                 "start_time": "20.62",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "ties"
#                     }
#                 ],
#                 "end_time": "21.17",
#                 "start_time": "20.91",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.995",
#                         "content": "to"
#                     }
#                 ],
#                 "end_time": "21.26",
#                 "start_time": "21.17",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.985",
#                         "content": "mathematical"
#                     }
#                 ],
#                 "end_time": "21.86",
#                 "start_time": "21.26",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "optimization"
#                     }
#                 ],
#                 "end_time": "22.66",
#                 "start_time": "21.86",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.0",
#                         "content": ","
#                     }
#                 ],
#                 "type": "punctuation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "which"
#                     }
#                 ],
#                 "end_time": "22.9",
#                 "start_time": "22.67",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "delivers"
#                     }
#                 ],
#                 "end_time": "23.38",
#                 "start_time": "22.9",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.973",
#                         "content": "methods"
#                     }
#                 ],
#                 "end_time": "23.88",
#                 "start_time": "23.38",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.0",
#                         "content": ","
#                     }
#                 ],
#                 "type": "punctuation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "theory"
#                     }
#                 ],
#                 "end_time": "24.42",
#                 "start_time": "23.89",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "and"
#                     }
#                 ],
#                 "end_time": "24.58",
#                 "start_time": "24.43",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "application"
#                     }
#                 ],
#                 "end_time": "25.08",
#                 "start_time": "24.58",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "domains"
#                     }
#                 ],
#                 "end_time": "25.44",
#                 "start_time": "25.08",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.997",
#                         "content": "to"
#                     }
#                 ],
#                 "end_time": "25.53",
#                 "start_time": "25.44",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "the"
#                     }
#                 ],
#                 "end_time": "25.61",
#                 "start_time": "25.53",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "1.0",
#                         "content": "field"
#                     }
#                 ],
#                 "end_time": "26.09",
#                 "start_time": "25.61",
#                 "type": "pronunciation"
#             },
#             {
#                 "alternatives": [
#                     {
#                         "confidence": "0.0",
#                         "content": "."
#                     }
#                 ],
#                 "type": "punctuation"
#             }
#         ],
#         "transcripts": [
#             {
#                 "transcript": "Machine learning is employed in a range of computing tasks where designing and programming explicit algorithms with good performance as difficult or infeasible. Example applications include email filtering, detection of network intruders and computer vision. Machine learning is closely related to computational statistics, which also focuses on predictions making through the use of computer. It has strong ties to mathematical optimization, which delivers methods, theory and application domains to the field."
#             }
#         ]
#     },
#     "status": "COMPLETED"
# }
